# %%
#IMPORTS 
import sys
import numpy as np
import matplotlib.pyplot as plt
sys.path.append(r"C:\Users\EmilR\Documents\GitHub\MoleculeSim\ownSim")

import molecules as mc
import forces as fc
import random
import copy

# %% [markdown]
# # Spawn grid molecules

# %%
import itertools
def grid_points(box_size,radius, spacing):
  x = np.arange(radius + spacing, box_size[0]- radius- spacing, step = 2*radius + spacing)
  y = np.arange(radius+ spacing, box_size[1]- radius- spacing, step = 2*radius + spacing)
  z = np.arange(radius+ spacing, box_size[2]- radius- spacing, step = 2*radius + spacing)
  all_combinations = list(itertools.product(x,y,z))
  print(x,y,z)
  return [np.array(comb) for comb in all_combinations]

# %%
box_size = np.array([1000.,1000.,800.])
radius = 100.
spacing = 50
seed = 42
combs = grid_points(box_size, radius, spacing)
molecules = [mc.Molecule(pos, radius) for pos in combs]
uni = mc.SimpleUniverse(box_size, len(molecules), np.repeat(radius,len(molecules)), seed, own_molecules= molecules)
state = uni.get_state()
print("pos", molecules[0].pos,type(molecules[0].pos))
print(state)
# Out:
# [150. 400. 650.] [150. 400. 650.] [150. 400.]
# pos [150. 150. 150.] <class 'numpy.ndarray'>
# [[150. 150. 150.]
#  [150. 150. 400.]
#  [150. 400. 150.]
#  [150. 400. 400.]
#  [150. 650. 150.]
#  [150. 650. 400.]
#  [400. 150. 150.]
#  [400. 150. 400.]
#  [400. 400. 150.]
#  [400. 400. 400.]
#  [400. 650. 150.]
#  [400. 650. 400.]
#  [650. 150. 150.]
#  [650. 150. 400.]
#  [650. 400. 150.]
#  [650. 400. 400.]
#  [650. 650. 150.]
#  [650. 650. 400.]]

# %%
# MAYAVI IMPORTS
import traits
from mayavi import mlab
import numpy as np
from __future__ import absolute_import, division, print_function
from mayavi import mlab
import numpy as np
import math

# %%
test = []
for i in range(len(uni.molecules)):
  if all(uni.molecules[i].pos == molecules[i]):
    test.append("same")
  else: 
    test.append("dif")
#print(test)
for i in range(5):
  print(combs[i])
  print(uni.molecules[i].pos)
# Out:
# [150. 150. 150.]
# [150. 150. 150.]
# [150. 150. 400.]
# [150. 150. 400.]
# [150. 400. 150.]
# [150. 400. 150.]
# [150. 400. 400.]
# [150. 400. 400.]
# [150. 650. 150.]
# [150. 650. 150.]

# %%
#params
num_steps = 20000

# %%
points = []

# Perform Simulation
for i in range(num_steps):
  #randomly select a molecule
  mol = uni.select_molecule()
  #keep proposing new steps until one is accepted
  mc.step(uni,mol)
  #store intermediate results?
  points.append(uni.get_state())


#points shape = 20x20x3
# Out:
# energy -0.13406274615268338 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.17024633937214323 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.09961369427394938 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.0995181544111247 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.09949626625801132 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.13258301574685818 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.10325808142090653 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.11108194645880093 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.10029473913090917 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.1342361924650308 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.09705351519502567 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.09541584448473894 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.14249280971821826 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.13237025410971417 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.139171860186835 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.10335988538610914 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.1414068033499159 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.10547682469243286 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.10833606468948562 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.09620481131269479 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.16907148677841 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.13952969028817236 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.12761735084880144 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.13971108430119383 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.13051676637911616 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.12834696380775584 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.13687405191442795 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.13417369537919333 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.12988773579460647 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.18679675123240372 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.12377767198478591 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.092774285689905 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.13880318049396861 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.09335452600119004 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.11821906213026959 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.13605286175772724 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.1087562158412525 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.09848425176376213 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.0844232067729762 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.1251430375815176 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.13818823776477734 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.151097076540669 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.1568353557164352 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.09646374018492875 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.10661648387606948 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.11169299102604809 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.08705251478013902 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.
<class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.5404357000733643 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.0714804133755137 <class 'numpy.float64'>
# am i in box? True
# im in
# energy -0.14499981731599584 <class 'numpy.float64'>
# am i in box? True
# im in
# ...
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# am i in box? True
# im in
# encountered nan energy, converting to 0 (consider fixing this)
#
# am i in box? True
# im in
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 8
#       6 mol = uni.select_molecule()
#       7 #keep proposing new steps until one is accepted
# ----> 8 mc.step(uni,mol)
#       9 #store intermediate results?
#      10 points.append(uni.get_state())
#
# File ~\Documents\GitHub\MoleculeSim\ownSim\molecules.py:83, in step(universe, molecule, window)
#      80 mol_copy.move(delta_pos)
#      82 #calculate energy for potential new location
# ---> 83 e_new = get_energy(molecule, universe, mol_copy)
#      85 # if move is accepted, make the real molecule perform the step
#      86 accepted = fc.accept_move(e_current,e_new, BETA)
#
# File ~\Documents\GitHub\MoleculeSim\ownSim\molecules.py:48, in get_energy(mol_fixed, universe, mol_moved)
#      46 del nbs[idx]
#      47 if mol_moved != None: # if we moved the molecule
# ---> 48   energy = sum([universe.force_fun(mol_moved,m2) for m2 in nbs])
#      49 else: #just compute energy for the fixed/previous molecule
#      50   energy = sum([universe.force_fun(mol_fixed,m2) for m2 in nbs])
#
# File ~\Documents\GitHub\MoleculeSim\ownSim\molecules.py:48, in <listcomp>(.0)
#      46 del nbs[idx]
#      47 if mol_moved != None: # if we moved the molecule
# ---> 48   energy = sum([universe.force_fun(mol_moved,m2) for m2 in nbs])
#      49 else: #just compute energy for the fixed/previous molecule
#      50   energy = sum([universe.force_fun(mol_fixed,m2) for m2 in nbs])
#
# File ~\Documents\GitHub\MoleculeSim\ownSim\forces.py:90, in total_force_molecule(m1, m2)
#      89 def total_force_molecule(m1,m2):
# ---> 90   return vdw(m1,m2) + elec_rep(m1,m2) + steric(m1,m2)
#
# File ~\Documents\GitHub\MoleculeSim\ownSim\forces.py:53, in elec_rep(m1, m2)
#      52 def elec_rep(m1,m2):
# ---> 53   U_el = EPS0 * EPS * (PHII**2) * np.log(1 + np.exp( -(mc.dist(m1,m2)-m1.radius-m2.radius)))
#      54   #print(np.sqrt(2/(EPS0*EPS*np.log(1 + np.exp(dist(m1,m2)-m1.radius-m2.radius)))))
#      55   return U_el
#
# File ~\Documents\GitHub\MoleculeSim\ownSim\molecules.py:240, in dist(m1, m2)
#     239 def dist(m1,m2):
# --> 240   return np.linalg.norm(m2.pos - m1.pos)
#
# File d:\Program_files\anaconda3\envs\OSTV2\lib\site-packages\numpy\linalg\linalg.py:2552, in norm(x, ord, axis, keepdims)
#    2550     sqnorm = x_real.dot(x_real) + x_imag.dot(x_imag)
#    2551 else:
# -> 2552     sqnorm = x.dot(x)
#    2553 ret = sqrt(sqnorm)
#    2554 if keepdims:
#
# KeyboardInterrupt:

# %%
plt = mlab.points3d(points[0][:, 0], points[0][:, 1], points[0][:, 2])

@mlab.animate(delay=100, ui = True)
def anim():
    f = mlab.gcf()
    while True:
        #temp = "step: "
        for step in range(num_steps):
            temp = "step: " + str(step)
            #print(temp, end = "\r")
            x = points[step][:, 0]
            y = points[step][:, 1]
            z = points[step][:, 2]
        #for (x, y, z) in zip(xs, ys, zs):
            #plt.mlab_source.set(x=x, y=y, z=z)
            #mlab.text3d(box_size[0],box_size[1],box_size[2], text = temp)
            yield


anim()
mlab.show()
